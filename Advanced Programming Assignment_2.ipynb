# %% [markdown]
# ## **Advanced Programming Assignment_2**
#
# #### **Name: Dejene Seboka**
# #### **Date: May 2 2026**
# #### **Student ID: GSR/6247/18**

# %% [markdown]
# ### **Part 1: Basic Input & Output**

# %%
x = "Abel"
y = 20
print("Hello",x, "! you are", y, "old")
# Out:
# Hello Abel ! you are 20 old

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")

print(f"Hello {name}! You are {age} years old.")
# Out:
# Enter your name:  Dejene
# Enter your age:  25
# Hello Dejene! You are 25 years old.

# %% [markdown]
# ### **Part 2: Even or Odd Checker**

# %%
x = 10
print("even") if x % 2 == 0 else print("odd")
# Out:
# even

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print(f"{num} is Even")
else:
    print(f"{num} is Odd")
# Out:
# Enter a number:  11
# 11 is Odd

# %% [markdown]
# ### **Part 3: Loop Practice**

# %%
for i in range(1, 21):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz

# %% [markdown]
# ### **Part 4: List Operations**

# %%
# Create a list of 5 numbers
numbers = [24, 7, 56, 12, 3]

# Calculate the values
largest = max(numbers)
smallest = min(numbers)
total_sum = sum(numbers)

# Print the results
print(f"List: {numbers}")
print(f"The largest number: {largest}")
print(f"The smallest number: {smallest}")
print(f"The sum of all numbers: {total_sum}")
# Out:
# List: [24, 7, 56, 12, 3]
# The largest number: 56
# The smallest number: 3
# The sum of all numbers: 102

# %% [markdown]
# ### **Part 5: Dictionary Task**

# %%
# Initial dictionary
student = {
    "name": "Abel",
    "age": 20,
    "grade": "A"
}

# Add a new key "city"
student["city"] = "Addis Ababa"

# Update the grade
student["grade"] = "A+"   # updated value

# Print all keys and values using a loop
for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Abel
# age : 20
# grade : A+
# city : Addis Ababa

# %% [markdown]
# ### **Part 6: Function**

# %%
# Define the function
def calculate_area(length, width):
    return length * width

# Call the function
area = calculate_area(5, 3)

# Print the result
print("Area of the rectangle is:", area)
# Out:
# Area of the rectangle is: 15

# %% [markdown]
# ### **Part 7: Mini Project**

# %%
# Simple Calculator

# 1. Take two numbers from the user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

# 2. Ask for an operation
operation = input("Enter operation (+, -, *, /): ")

# 3. Perform calculation and print result
if operation == "+":
    result = num1 + num2
elif operatioThen == "-":
    result = num1 - num2
elif operation == "*":
    result = num1 * num2
elif operation == "/":
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! Division by zero."
else:
    result = "Invalid operation!"

print("Result:", result)
# Out:
# Enter first number:  6
# Enter second number:  3
# Enter operation (+, -, *, /):  +
# Result: 9.0

# %% [markdown]
# #### **by assigning virable**

# %%
num1 = 10
num2 = 5

print(f"{num1} + {num2} = {num1 + num2}")
print(f"{num1} - {num2} = {num1 - num2}")
print(f"{num1} * {num2} = {num1 * num2}")

if num2 != 0:
    print(f"{num1} / {num2} = {num1 / num2}")
else:
    print("Division by zero not allowed")
# Out:
# 10 + 5 = 15
# 10 - 5 = 5
# 10 * 5 = 50
# 10 / 5 = 2.0

# %%
# Take all inputs first
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Enter operation (+, -, *, /): ")

# Process
if operation == "+":
    result = num1 + num2
elif operation == "-":
    result = num1 - num2
elif operation == "*":
    result = num1 * num2
elif operation == "/":
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! Division by zero"
else:
    result = "Invalid operation"

# Print everything at once
print("\n----- RESULT -----")
print(f"First number : {num1}")
print(f"Second number: {num2}")
print(f"Operation    : {operation}")
print(f"Result       : {result}")
# Out:
# Enter first number:  5
# Enter second number:  7
# Enter operation (+, -, *, /):  -
# ----- RESULT -----
# First number : 5.0
# Second number: 7.0
# Operation    : -
# Result       : -2.0

# %% [markdown]
# ## **Thank you!**
